# %%
"""import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Veri oluşturma
x = np.arange(10000)
y = 17 * x + 5694

# Veriyi eğitim ve test setlerine ayırma
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# Model oluşturma ve eğitme
model = LinearRegression()
model.fit(x_train.reshape(-1, 1), y_train)

# Test verisi ile modelin performansını değerlendirme
score = model.score(x_test.reshape(-1, 1), y_test)
print(f"Modelin doğruluk oranı: {score}")

# Tahmin yapma
prediction = model.predict([[5000]])
print(f"Modelin tahmini: {prediction[0]}")"""

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Veri oluşturma
x = np.arange(100).reshape(-1, 1)
y = 3 * x + 527

# Veriyi eğitim ve test setlerine ayırma
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# Polinom özellikleri oluşturma
poly = PolynomialFeatures(degree=3)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.fit_transform(x_test)

# Modeli eğitme
model = LinearRegression()
model.fit(x_train_poly, y_train)

score = model.score(x_test_poly, y_test)
print(f"Modelin doğruluk oranı: {score}")
plt.plot(x_test,model.predict(x_test_poly),"b")
# Out:
# Modelin doğruluk oranı: 1.0

# %%
# Tahmin yapma
prediction = model.predict(poly.fit_transform([[3]]))
print(f"Modelin tahmini: {prediction[0]}")
# Out:
# Modelin tahmini: [536.]

# %%
import seaborn as sbn
import pandas as pd
dataFrame = pd.DataFrame(x_train_poly)
sbn.pairplot(dataFrame)

# %%
import pandas as pd
df1 = pd.DataFrame(x_test)
df1[1] = pd.DataFrame(model.predict(x_test_poly))
df1.sort_values(by=0,ascending=True)
# Out:
#      0      1
# 4    1  530.0
# 18  13  566.0
# 11  14  569.0
# 17  15  572.0
# 13  17  578.0
# 9   24  599.0
# 16  27  608.0
# 0   31  620.0
# 10  33  626.0
# 19  39  644.0
# 2   42  653.0
# 3   46  665.0
# 8   76  755.0
# 1   79  764.0
# 14  80  767.0
# 5   83  776.0
# 7   86  785.0
# 12  87  788.0
# 15  91  800.0
# 6   98  821.0
